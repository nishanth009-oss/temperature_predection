# %%
import pandas as pd
weather=pd.read_csv("weather.csv", index_col="DATE")
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.62
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.08
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2022-10-17   NaN   NaN  0.08   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-18   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-19   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN  10.0  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT17  WT18  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   1.0   NaN   NaN   NaN
# 1970-01-04   NaN   1.0   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2022-10-17   NaN   NaN   NaN   NaN   NaN
# 2022-10-18   NaN   NaN   NaN   NaN   NaN
# 2022-10-19   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN   NaN   NaN   NaN
#
# [19287 rows x 44 columns]

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]
weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH        9672
# ACSH        9671
# AWND        5116
# FMTM        9163
# PGTM        7018
# PRCP           0
# SNOW           0
# SNWD           2
# TAVG       13123
# TMAX           0
# TMIN           0
# TSUN       19256
# WDF1        9676
# WDF2        9618
# WDF5        9701
# WDFG       14166
# WDFM       19286
# WESD       13216
# WSF1        9673
# WSF2        9618
# WSF5        9702
# WSFG       11824
# WSFM       19286
# WT01       12155
# WT02       18034
# WT03       18000
# WT04       18951
# WT05       18923
# WT06       19106
# WT07       19179
# WT08       15371
# WT09       19147
# WT11       19273
# WT13       17102
# WT14       18400
# WT15       19245
# WT16       12710
# WT17       19227
# WT18       18120
# WT21       19282
# WT22       19238
# WV01       19286
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
valid_columns=weather.columns[null_pct<.05]
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid_columns].copy()
weather.columns=weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-10-17    67    54
# 2022-10-18    58    48
# 2022-10-19    56    43
# 2022-10-20    61    44
# 2022-10-21    64    43
#
# [19287 rows x 7 columns]

# %%
weather=weather.ffill()
null_pct=weather.apply(pd.isnull).sum()
null_pct
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index=pd.to_datetime(weather.index)
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"]=weather.shift(-1)["tmax"]
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43     NaN
#
# [19287 rows x 8 columns]

# %%
weather=weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    64.0
#
# [19287 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge
rr=Ridge(alpha=.1)

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
import pandas as pd

def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i, :]
        test = weather.iloc[i:(i + step), :]
        
        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    
    return pd.concat(all_predictions).reset_index(drop=True)
predictions = backtest(weather, rr, predictors)

# %%
predictions.head(10)
# Out:
#    actual  prediction       diff
# 0    43.0   50.229324   7.229324
# 1    42.0   43.673798   1.673798
# 2    41.0   41.579150   0.579150
# 3    36.0   43.961887   7.961887
# 4    30.0   40.204726  10.204726
# 5    29.0   33.233571   4.233571
# 6    28.0   34.262033   6.262033
# 7    39.0   30.563236   8.436764
# 8    36.0   41.451611   5.451611
# 9    32.0   41.883745   9.883745

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# np.float64(5.139326679660841)

# %%
predictions["diff"].mean()
# Out:
# np.float64(5.139326679660841)

# %%
def pct_diff(old, new):
    return (new - old)/old

def compute_rolling(weather,horizon,col):
    label=f"rolling_{horizon}_{col}"
    weather[label]=weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"]=pct_diff(weather[label],weather[col])
    return weather

rolling_horizons=[3,14]
for horizon in rolling_horizons:
    for col in ["tmax","tmin","prcp"]:
        weather = compute_rolling(weather, horizon, col)

weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-01    28    22    31.0             NaN                 NaN
# 1970-01-02    31    22    38.0             NaN                 NaN
# 1970-01-03    38    25    31.0       32.333333            0.175258
# 1970-01-04    31    23    35.0       33.333333           -0.070000
# 1970-01-05    35    21    36.0       34.666667            0.009615
# ...          ...   ...     ...             ...                 ...
# 2022-10-17    67    54    58.0       67.000000            0.000000
# 2022-10-18    58    48    56.0       63.666667           -0.089005
# 2022-10-19    56    43    61.0       60.333333           -0.071823
# 2022-10-20    61    44    64.0       58.333333            0.045714
# 2022-10-21    64    43    64.0       60.333333            0.060773
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                 NaN             NaN
# 1970-01-02             NaN                 NaN             NaN
# 1970-01-03       23.000000            0.086957        0.006667
# 1970-01-04       23.333333           -0.014286        0.006667
# 1970-01-05       23.000000           -0.086957        0.006667
# ...                    ...                 ...             ...
# 2022-10-17       51.000000            0.058824        0.026667
# 2022-10-18       51.333333           -0.064935        0.026667
# 2022-10-19       48.333333           -0.110345        0.026667
# 2022-10-20       45.000000           -0.022222        0.000000
# 2022-10-21       43.333333           -0.007692        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-01                 NaN              NaN                  NaN
# 1970-01-02                 NaN              NaN                  NaN
# 1970-01-03                 2.0              NaN                  NaN
# 1970-01-04                -1.0              NaN                  NaN
# 1970-01-05                -1.0              NaN                  NaN
# ...                        ...              ...                  ...
# 2022-10-17                 2.0        67.142857            -0.002128
# 2022-10-18                -1.0        67.285714            -0.138004
# 2022-10-19                -1.0        67.000000            -0.164179
# 2022-10-20                 NaN        65.928571            -0.074756
# 2022-10-21                 NaN        65.071429            -0.016465
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03              NaN                  NaN              NaN
# 1970-01-04              NaN                  NaN              NaN
# 1970-01-05              NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2022-10-17        50.785714             0.063291         0.233571
# 2022-10-18        50.857143            -0.056180         0.135000
# 2022-10-19        50.000000            -0.140000         0.095714
# 2022-10-20        49.428571            -0.109827         0.095714
# 2022-10-21        48.500000            -0.113402         0.095714
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-01                  NaN
# 1970-01-02                  NaN
# 1970-01-03                  NaN
# 1970-01-04                  NaN
# 1970-01-05                  NaN
# ...                         ...
# 2022-10-17            -0.657492
# 2022-10-18            -1.000000
# 2022-10-19            -1.000000
# 2022-10-20            -1.000000
# 2022-10-21            -1.000000
#
# [19287 rows x 20 columns]

# %%
weather=weather.iloc[14:,:]
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-29  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-30  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-31  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-02-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-02-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.11   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-29    49    40    47.0       41.666667            0.176000
# 1970-01-30    47    24    36.0       45.333333            0.036765
# 1970-01-31    36    22    48.0       44.000000           -0.181818
# 1970-02-01    48    34    49.0       43.666667            0.099237
# 1970-02-02    49    36    50.0       44.333333            0.105263
# ...          ...   ...     ...             ...                 ...
# 2022-10-17    67    54    58.0       67.000000            0.000000
# 2022-10-18    58    48    56.0       63.666667           -0.089005
# 2022-10-19    56    43    61.0       60.333333           -0.071823
# 2022-10-20    61    44    64.0       58.333333            0.045714
# 2022-10-21    64    43    64.0       60.333333            0.060773
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01